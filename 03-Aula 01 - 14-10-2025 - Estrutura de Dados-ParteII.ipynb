# %% [markdown]
# # FGV EPGE - Escola de Pós-Graduação em Economia
# ---
# ## Mestrado Profissional em Economia
# ### Decisões Baseadas em Dados I - 2025-4
# ---
# #### Professor: Rafael Martins de Souza (rafael.souza@fgv.br)
# ##### Doutor em Economia (EPGE, 2009), Mestre (UFRJ, 2003) e Bacharel em Estatística (ENCE, 2000).
# ---

# %% [markdown]
# # Aula 1 - Parte III
#
#
# - Principais Estruturas de Dados (Parte 2)

# %% [markdown]
# ## Estruturas de Dados
#
# - <font color='green'>Tipos numéricos (visto)</font>
# - <font color = 'green'>Lista (visto parcialmente)</font>
# - String
# - Conjuntos
# - Dicionários
# - Tuplas

# %% [markdown]
# Boa fonte para conseguir cores
#
# https://htmlcolorcodes.com/

# %% [markdown]
# ### Continuação: Lista
#
# #### Referências interessantes
#
# - https://docs.python.org/3/tutorial/introduction.html#lists
#
# - https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Referência sobre indexação:
# - https://docs.python.org/3/reference/expressions.html
# - https://docs.python.org/3/faq/programming.html

# %%
a = 1
lista = [1,2, a]
print(lista)
a = 3
lista = [1,2, a]
print(lista)
# Out:
# [1, 2, 1]
# [1, 2, 3]

# %%
lista[2] = 3

# %%
lista
# Out:
# [1, 2, 3]

# %%
a
# Out:
# [3]

# %%
a = [1]
lista = [a, 3,4]
print(lista)
a[0] = 3
print(lista)
# Out:
# [[1], 3, 4]
# [[3], 3, 4]

# %%
a = [1]
b = a
a[0] = 3
print(b)
# Out:
# [3]

# %% [markdown]
# ### Sort

# %%
lista3 = [1,100,30,50,70]

# %%
lista3
# Out:
# [1, 100, 30, 50, 70]

# %% [markdown]
# Colocando em ordem (se os elementos forem apenas numéricos!)

# %%
lista3.sort()

# %%
print(lista3)
# Out:
# [1, 30, 50, 70, 100]

# %%
lista3.append([200, 300])

# %%
lista3
# Out:
# [1, 30, 50, 70, 100, [200, 300]]

# %%
lista3.append((300, 500))

# %%
lista3
# Out:
# [1, 30, 50, 70, 100, [200, 300], (300, 500)]

# %%
type(lista3[6])
# Out:
# tuple

# %%
lista3[0] = 3

# %%
lista3
# Out:
# [3, 30, 50, 70, 100, [200, 300], (300, 500)]

# %%
tupla = 300, 500

# %%
tupla[0] = 200
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2013726098.py in <cell line: 0>()
# ----> 1 tupla[0] = 200
#
# TypeError: 'tuple' object does not support item assignment

# %%
lista3.extend([1,2,3])

# %%
lista3
# Out:
# [3, 30, 50, 70, 100, [200, 300], (300, 500), 1, 2, 3]

# %%
lista3.insert(2,[100, 200])

# %%
lista3
# Out:
# [3, 30, [100, 200], 100, 50, 70, 100, [200, 300], (300, 500), 1, 2, 3, 1, 2, 3]

# %%
lista3[2]
# Out:
# [100, 200]

# %%
lista3
# Out:
# [3, 30, 50, 70, 100, [200, 300], (300, 500), 1, 2, 3, 1, 2, 3]

# %%
lista3[5]
# Out:
# [200, 300]

# %%
lista3.extend([100])

# %%
print(lista3)
# Out:
# [3, 30, [100, 200], 100, 50, 70, 100, [200, 300], (300, 500), 1, 2, 3, 1, 2, 3, 100]

# %%
lista33 = [1,'string',100,50,10]
print(lista33)
# Out:
# [1, 'string', 100, 50, 10]

# %% [markdown]
# Para que o comando sort funcione é necessário que todos os objetos da lista sejam do mesmo tipo.

# %%
lista33.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2301369017.py in <cell line: 0>()
# ----> 1 lista33.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
listanomes = ["Sandro Mendes", "Marlon", "Marlon Marques"]
listanomes
# Out:
# ['Sandro Mendes', 'Marlon', 'Marlon Marques']

# %%
listanomes.sort()
listanomes
# Out:
# ['Marlon', 'Marlon Marques', 'Sandro Mendes']

# %%
listanomes.sort(reverse=True)
listanomes
# Out:
# ['Sandro Mendes', 'Marlon Marques', 'Marlon']

# %%
print(listanomes)
listanomes = sorted(listanomes)
print(listanomes)
#print(listanomes)
#Se eu quiser modificar o objeto.
#listanomes = sorted(listanomes)
# Out:
# ['Sandro Mendes', 'Marlon Marques', 'Marlon']
# ['Marlon', 'Marlon Marques', 'Sandro Mendes']

# %% [markdown]
# Acessando elementos (com uma lista um pouco mais complicada)

# %%
lista4 = [[[2,1],7,9,3,3,2,[2,6]],4,5,7]

# %%
lista4[0]
# Out:
# [[2, 1], 7, 9, 3, 3, 2, [2, 6]]

# %%
len(lista4)
# Out:
# 4

# %%
len(lista4[0])
# Out:
# 7

# %%
len(lista4[0][0])
# Out:
# 2

# %% [markdown]
# Qual a posição de determinado elemento?

# %%
# Qual é a posição do elemento 2 na lista4[0]?
lista4[0].index(2)
# Out:
# 5

# %%
print(lista4[0][0][0])
# Out:
# 2

# %%
lista4.index(4)
# Out:
# 1

# %%
lista4[0]
# Out:
# [[2, 1], 7, 9, 3, 3, 2, [2, 6]]

# %% [markdown]
# len() de 'length' dá o tamanho do objeto

# %%
len(lista4)
# Out:
# 4

# %% [markdown]
# O comando pop() permite retirar objetos da lista.

# %%
#print(lista4)
lista4[0].pop()
#lista4[0]
#lista4
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2127668305.py in <cell line: 0>()
#       1 #print(lista4)
# ----> 2 lista4[0].pop()
#       3 #lista4[0]
#       4 #lista4
#
# IndexError: pop from empty list

# %%
lista4
# Out:
# [[], 4, 5, 7]

# %%
print(lista4[0])
# Out:
# []

# %%
lista4[0].pop(0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-33351320.py in <cell line: 0>()
# ----> 1 lista4[0].pop(0)
#
# IndexError: pop from empty list

# %%
lista4
# Out:
# [[], 4, 5, 7]

# %%
lista4[0]=0

# %%
lista4
# Out:
# [0, 4, 5, 7]

# %%
type(lista4[0])
# Out:
# int

# %%
lista4[0]
# Out:
# [7, 9, 3, 3, 2]

# %%
lista4
# Out:
# [[7, 9, 3, 3, 2], 4, 5, 7]

# %%
listathiago = [1,2,3,4,5,6]
listathiago.pop()
# Out:
# 6

# %%
listathiago
# Out:
# [1, 2, 3, 4, 5]

# %%
listathiago.pop(0)
# Out:
# 1

# %%
listathiago
# Out:
# [2, 3, 4, 5]

# %%
listathiago[0].pop
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2166001603.py in <cell line: 0>()
# ----> 1 listathiago[0].pop
#
# AttributeError: 'int' object has no attribute 'pop'

# %%
type(listathiago[0])
# Out:
# int

# %% [markdown]
# O comando append() permite adicionar elementos à lista.

# %%
lista4[0].append('string_qualquer')
print(lista4[0])
# Out:
# [7, 9, 3, 3, 2, 'string_qualquer']

# %%
lista4[0].pop()
print(lista4)
lista4[0]
# Out:
# [[7, 9, 3, 3, 2], 4, 5, 7]
# [7, 9, 3, 3, 2]

# %%
lista = [0,1,2,3]
print(lista)
del lista[0]
print(lista)
# Out:
# [0, 1, 2, 3]
# [1, 2, 3]

# %% [markdown]
# Para somar usamos uma sintaxe um pouco diferente. "Sum" é uma dentre várias funções built-in

# %%
print(lista4)
#print(sum(lista4[0]))
#print(sum(lista4))
#Não consigo somar listas e inteiros/floats
#print(lista4[0][0])
#Não consigo "somar" um inteiro ou float
#print(sum(lista4[0][0]))
# Out:
# [[7, 9, 3, 3, 2], 4, 5, 7]

# %% [markdown]
# ### Count
# Count dá a frequência determinado elemento aparece na lista

# %%
lista4 = [[[2,1],7,9,3,3,2,[2,6]],4,5,7]
lista4
# Out:
# [[[2, 1], 7, 9, 3, 3, 2, [2, 6]], 4, 5, 7]

# %%
lista4.pop()
# Out:
# 7

# %%
lista4[0].pop()
# Out:
# [2, 6]

# %%
lista4
# Out:
# [[[2, 1], 7, 9, 3, 3, 2], 4, 5]

# %%
lista4[0]
# Out:
# [[2, 1], 7, 9, 3, 3, 2, [2, 6]]

# %%
lista4[0][1]
# Out:
# 7

# %%
listaluiza  = [[[2,1],[7,9,3,3,2],[2,6]],4,5,7]

# %%
listaluiza[0][1]
# Out:
# [7, 9, 3, 3, 2]

# %%
lista4[0]
# Out:
# 0

# %%
lista4[0]
# Out:
# [[2, 1], 7, 9, 3, 3, 2, [2, 6]]

# %%
lista4[0].count(3)
# Out:
# 2

# %%
lista4[0].count('3')
# Out:
# 0

# %%
3 == '3'
# Out:
# False

# %%
a = 3
print(type(a))
b = "3"
print(type(b))
a == b
# Out:
# <class 'int'>
# <class 'str'>
# False

# %%
'1'+'2'
# Out:
# '12'

# %%
'Brasil'+ ' ' + 'Campeão'
# Out:
# 'Brasil Campeão'

# %%
lista4[0].count([3])
# Out:
# 0

# %%
lista4[0].count(6)
# Out:
# 0

# %%
lista4[0].count([2, 1])
# Out:
# 1

# %%
lista4
# Out:
# [[[2, 1], 7, 9, 3, 3, 2, [2, 6]], 4, 5, 7]

# %%
lista4[0]
# Out:
# [7, 9, 3, 3, 2]

# %%
print(lista4)
print(lista4[0][3])
# Out:
# [[7, 9, 3, 3, 2], 4, 5, 7]
# 3

# %%
lista4[0].count(3)
# Out:
# 2

# %%
print(lista4)
lista5 = lista4[-1]
print(lista5)
# Out:
# [[7, 9, 3, 3, 2], 4, 5, 7]
# 7

# %% [markdown]
# Exercício Aula 2
#
# Calcular a média dos elementos de uma lista.

# %%
lista_exercicio = [30, 17, 47, 37, 34, 45, 5, 45, 48, 22, 10, 18, 2, 48, 47, 9, 17, 43, 46, 37]
print(lista_exercicio)
# Out:
# [30, 17, 47, 37, 34, 45, 5, 45, 48, 22, 10, 18, 2, 48, 47, 9, 17, 43, 46, 37]

# %%
sum(lista_exercicio)/len(lista_exercicio)
# Out:
# 30.35

# %% [markdown]
# ### max

# %%
max(lista_exercicio)
# Out:
# 48

# %% [markdown]
# ### min

# %%
min(lista_exercicio)
# Out:
# 2

# %%
lista_exercicio = [30, 17, 47, 37, 34, 45, 5, 45, 48, 22, 10, 18, 2, 48, 47, 9, 17, 43, 46, 37]
lista_exercicio.sort(reverse=True)
print(lista_exercicio)
a = lista_exercicio.pop(-2)
print(a)
print(lista_exercicio)
# Out:
# [48, 48, 47, 47, 46, 45, 45, 43, 37, 37, 34, 30, 22, 18, 17, 17, 10, 9, 5, 2]
# 5
# [48, 48, 47, 47, 46, 45, 45, 43, 37, 37, 34, 30, 22, 18, 17, 17, 10, 9, 2]

# %% [markdown]
# ### Tipo String:
#
# #### Referências:
#
# - https://docs.python.org/3/library/stdtypes.html#string-methods
# - https://docs.python.org/3/library/stdtypes.html#old-string-formatting
# - https://www.educative.io/edpresso/why-are-strings-in-python-immutable
#
# Strings são sequências de caracteres dispostos, necessariamente, entre aspas simples ou duplas.
#
# Comandos interessantes: capitalize, count, find, format, join, replace, split, startswith, upper

# %%
s1 = 'data science'
s2 = 'mathematics'
s3 = 'aluno'
s4 = 'minha nota final foi '

# %%
s1
# Out:
# 'data science'

# %%
type(s1)
# Out:
# str

# %% [markdown]
# #### capitalize

# %%
s1 = s1.capitalize()

# %%
s1
# Out:
# 'Data science'

# %% [markdown]
# #### title

# %%
s1.title()
# Out:
# 'Data Science'

# %% [markdown]
# #### replace

# %%
s2 = 'Ssstring'

# %%
s2.replace('s','t')
# Out:
# 'Stttring'

# %%
print(s2)
# Out:
# Ssstring

# %%
s2.upper()
# Out:
# 'SSSTRING'

# %%
print(s2)
# Out:
# Ssstring

# %%
s2.lower()
# Out:
# 'ssstring'

# %%
print(s2)
# Out:
# Ssstring

# %% [markdown]
# Substituindo caracteres

# %%
s3
# Out:
# 'aluno'

# %%
s3.replace('o','a')
# Out:
# 'aluna'

# %%
s3
# Out:
# 'aluno'

# %%
s3 = s3.replace('o','a')

# %%
type(s3)
# Out:
# str

# %%
print(s3)
# Out:
# aluna

# %%
s3[-1]
# Out:
# 'a'

# %%
print(s3)
# Out:
# aluna

# %% [markdown]
# #### endswith

# %%
s3.endswith('a')
# Out:
# True

# %% [markdown]
# Concatenando strings

# %%
s4
# Out:
# 'minha nota final foi '

# %%
s4 + '10'
# Out:
# 'minha nota final foi 10'

# %% [markdown]
# Aspas duplas e aspas comuns tem a mesma função. Quando se quer uma dentro do texto, usar a outra para formar a string

# %%
s5 = "let's go to the classroom"
s5
# Out:
# "let's go to the classroom"

# %%
s55 = 'string com """""""aspas"'

# %%
s55
# Out:
# 'string com """""aspas"'

# %%
s6 = 'let\'s go to the classroom'
s6
# Out:
# "let's go to the classroom"

# %%
s10 = 'don\'t'
print(s10)
s10 = "don't"
print(s10)
# Out:
# don't
# don't

# %%
print(s10)
# Out:
# don't

# %%
s7 = '1'
s8 = "1"

# %%
s7 == s8
# Out:
# True

# %%
s7.isdigit()
# Out:
# True

# %%
s9 = 'Para quebrar a string em uma lista de várias strings basta usar o método "split"'

# %%
s9.split()
# Out:
# ['Para',
#  'quebrar',
#  'a',
#  'string',
#  'em',
#  'uma',
#  'lista',
#  'de',
#  'várias',
#  'strings',
#  'basta',
#  'usar',
#  'o',
#  'método',
#  '"split"']

# %%
s9
# Out:
# 'Para quebrar a string em uma lista de várias strings basta usar o método "split"'

# %%
type(s9)

# %%
listas9 = s9.split()

# %%
type(listas9)
# Out:
# list

# %%
s99 = 'o split pode usar outros separadores, por exemplo, vírgulas'

# %%
s99.split(',')
# Out:
# ['o split pode usar outros separadores', ' por exemplo', ' vírgulas']

# %%
listas99vig = s99.split(',')

# %%
type(listas99vig)
# Out:
# list

# %% [markdown]
# A "operação inversa" do split é o join

# %%
s9
# Out:
# 'Para quebrar a string em uma lista de várias strings basta usar o método "split"'

# %%
' '.join(s9.split())
# Out:
# 'Para quebrar a string em uma lista de várias strings basta usar o método "split"'

# %%
' '.join(s9)
# Out:
# 'P a r a   q u e b r a r   a   s t r i n g   e m   u m a   l i s t a   d e   v á r i a s   s t r i n g s   b a s t a   u s a r   o   m é t o d o   " s p l i t "'

# %%
s10 = 'O ibovespa subiu 1%'

# %%
s10 = s10.split()

# %%
s10
# Out:
# ['O', 'ibovespa', 'subiu', '1%']

# %%
''.join(s10)
# Out:
# 'Oibovespasubiu1%'

# %% [markdown]
# Print Formatting

# %%
atual_brml3 = 10.92
target_brml3 = 18.00

# %%
print(f'O preço-alvo da ação de BR Malls é R${target_brml3}, o que representa um upside de {round(100*(target_brml3/atual_brml3-1),2)}%.')
# Out:
# O preço-alvo da ação de BR Malls é R$18.0, o que representa um upside de 64.84%.

# %% [markdown]
# ### Tipo Conjunto (Set):
# Os itens são postos entre chaves e separados por vírgula.
#
# - Set são sequências **não-ordenadas** e **não-indexados** de itens únicos. Sets são mutáveis.
# - Itens duplicados não são considerados

# %%
numero_pares = {2,2,4,4,4,6,8,8,10,4}

# %%
numero_pares
# Out:
# {2, 4, 6, 8, 10}

# %%
numero_impares = {1,1,1,3,3,5,5,7,9}

# %%
numero_impares
# Out:
# {1, 3, 5, 7, 9}

# %%
numero_primos = {2,3,5,7}

# %%
numero_primos
# Out:
# {2, 3, 5, 7}

# %% [markdown]
# ## Difference

# %% [markdown]
# Para saber o que está no primeiro conjunto que não está no segundo

# %%
numero_pares.difference(numero_primos)
# Out:
# {4, 6, 8, 10}

# %% [markdown]
# ## intersection

# %% [markdown]
# Para saber a interseção entre os dois conjuntos

# %%
numero_impares.intersection(numero_primos)
# Out:
# {3, 5, 7}

# %%
lista1 = [1,2,3,5]
lista2 = [24,5,6]

# %%
type(numero_impares)
# Out:
# set

# %%
listanova = list(set(lista1).intersection(set(lista2)))
print(listanova)
# Out:
# [5]

# %%
lista_aleatoria = [1,2,3,'string',6,6,9,8,15,10000]

# %%
conjunto_aleatorio = set(lista_aleatoria)

# %% [markdown]
# Ordena como string

# %%
conjunto_aleatorio
# Out:
# {1, 10000, 15, 2, 3, 6, 8, 9, 'string'}

# %%
lista_aleatoria_sem_string = [1,2,3,6,6,9,8,15,10000]
conjunto_aleatorio_sem_string = set(lista_aleatoria_sem_string)
print(conjunto_aleatorio_sem_string)
# Out:
# {1, 2, 3, 6, 8, 9, 15, 10000}

# %%
seq = list(range(1,5))
print(seq)
tseq = tuple(range(1,5))
print(tseq)
# Out:
# [1, 2, 3, 4]
# (1, 2, 3, 4)
